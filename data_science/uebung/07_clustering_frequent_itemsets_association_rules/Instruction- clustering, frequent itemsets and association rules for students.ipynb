# %% [markdown]
# # Section 1: k-means and DBSCAN

# %%
# import necessary modules

import numpy as np
import pandas as pd
import csv
from matplotlib import pyplot as plt

# %% [markdown]
# ## Section 1.1: read and explore the data set data1.csv

# %%
#  Question 1: read data from the target CSV file 'data1.csv', store the file contents in variable 'data' which is Pandas.DataFrame,
# show the first 10 rows of variable 'data' and take a look at the structure of data in variable 'data' ??????

# read data from 'data1.csv' and store the data in variable 'data'
data = pd.read_csv('data1.csv')

# show first ten rows in 'data'
data.head(10)
# Out:
#           V1         V2
# 0   2.072345  -3.241693
# 1  17.936710  15.784810
# 2   1.083576   7.319176
# 3  11.120670  14.406780
# 4  23.711550   2.557729
# 5  24.169930  32.024780
# 6  21.665780   4.892855
# 7   4.693684  12.342170
# 8  19.211910  -1.121366
# 9   4.230391  -4.441536

# %%
# Question 2: make a variable 'v1_values' which is an array of values from column 'V1' in variable 'data' ??????
# Question 3: make a variable 'v2_values' which is an array of values from column 'V2' in variable 'data' ??????

v1_values = data['V1'].values
v2_values = data['V2'].values

plt.rcParams['figure.figsize'] = (20, 7)

# Question 4: draw scatter diagram for showing the distribution of data item in variable 'data'  by using variable 'v1_values' and 'v2_values'
# and find interesting features of the distribution of these data items ??????
plt.scatter(v1_values, v2_values, c='blue', s=10)
plt.show()

# %% [markdown]
# ## Section 1.2: experiments on k-means and DBSCAN by using data1.csv

# %%
# import k-means module and DBSCAN module from sklearn

from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN

# %%
# create input data that is stored in variable 'data_set' for k-means and DBSCAN
# variable 'data_set' is an array where each row is corresponding to the row in variable 'data' 

data_set = np.array(list(zip(v1_values, v2_values)))
data_set
# Out:
# array([[  2.072345,  -3.241693],
#        [ 17.93671 ,  15.78481 ],
#        [  1.083576,   7.319176],
#        ...,
#        [ 64.46532 , -10.50136 ],
#        [ 90.72282 , -12.25584 ],
#        [ 64.87976 , -24.87731 ]])

# %%
# Question 5: try values 3, 4 and 5 for the variable 'cluster_num' which represents the desired number of clusters
# and think deeply about which value for 'cluster_num' can help generate better clustering result and why ??????

cluster_num = 3

kmeans = KMeans(cluster_num).fit(data_set)
clusters = kmeans.labels_
centroids = kmeans.cluster_centers_

fig, plots = plt.subplots()
colors = ['r', 'g', 'b', 'y', 'm']
for cluster_index in range(cluster_num) :
    sub_set = np.array([data_set[i] for i in range(len(data_set)) if clusters[i] == cluster_index])
    if len(sub_set) == 0 :
        continue
    plots.scatter(sub_set[:,0], sub_set[:,1], s = 40, c = colors[cluster_index])
plots.scatter(centroids[:,0], centroids[:,1], marker = '*', s = 300, c = 'k')
plt.show()

# %%
# Answer for question 5: the best clustering result can be got when variable 'cluster_num' is set to 3 because for the 
# values 4 and 5, k-means algorithm will produce some clusters which are very close to each other, this is because 
# the original data set natually has three potential clusters for the data objects in it. This also indicates one weakness
# of k-means which is that if not a suitable value for the variable 'cluster_num' is given then bad results might be got.

# %%
# Question 6: run DBSCAN on the 'data_set', compare the result to the result from k-means when 'cluster_num = 3'
# and think about which result is better and why ??????

dbscan = DBSCAN(eps = 6, min_samples= 10).fit(data_set)
clusters = dbscan.labels_
cluster_indexs = np.unique(clusters).tolist()
print(cluster_indexs)

fig, plots = plt.subplots()
colors = ['r', 'g', 'b', 'y', 'm']
for cluster_index in cluster_indexs :
    sub_set = np.array([data_set[i] for i in range(len(data_set)) if clusters[i] == cluster_index])
    if len(sub_set) == 0 :
        continue
    plots.scatter(sub_set[:,0], sub_set[:,1], s = 40, c = colors[cluster_index])
# Out:
# [-1, 0, 1, 2]

# %%
# Answer for question 6: the better clustering result belongs to DBSCAN, becaue this algorithm generates four clusters,
# one cluster is for the outliers. This comparison shows the weakness of k-means which is that this algorithm cannot
# deal with outliers in the input data set. It can be seen from the result of k-means, there are some data objects
# that locate between two clusters are put in one cluster of the three clusters discovered.

# %% [markdown]
# # Section 2: Apriori algorithm and association rule algorithm

# %%
# import Apriori module and TransactionEncoder moduler and association module from mlxtend

from mlxtend.frequent_patterns import apriori
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import association_rules as arule

# %% [markdown]
# ## Section 2.1: learn to use Apriori algorithm and association rule algorithm from mlxtend

# %%
# read data from file repair.csv and show first 10 rows of this file

data_set = []

with open("repair.csv") as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        data_set.append(row)

print(len(data_set))
data_set[0:3][:]
# Out:
# 1104
# [['Register',
#   'Analyze Defect',
#   'Analyze Defect',
#   'Repair (Complex)',
#   'Repair (Complex)',
#   'Test Repair',
#   'Test Repair',
#   'Inform User',
#   'Archive Repair'],
#  ['Register',
#   'Analyze Defect',
#   'Analyze Defect',
#   'Repair (Simple)',
#   'Repair (Simple)',
#   'Test Repair',
#   'Test Repair',
#   'Restart Repair',
#   'Repair (Simple)',
#   'Inform User',
#   'Repair (Simple)',
#   'Test Repair',
#   'Test Repair',
#   'Archive Repair'],
#  ['Register',
#   'Analyze Defect',
#   'Analyze Defect',
#   'Repair (Complex)',
#   'Repair (Complex)',
#   'Test Repair',
#   'Test Repair',
#   'Inform User',
#   'Archive Repair']]

# %%
# learn to use TransactionEncoder module to convert an array to DataFrame for Apriori algorithm in mlxtend

te = TransactionEncoder()
te_ary = te.fit(data_set).transform(data_set)
data = pd.DataFrame(te_ary, columns = te.columns_)
data.head(10)
# Out:
#    Analyze Defect  Archive Repair  Inform User  Register  Repair (Complex)  \
# 0            True            True         True      True              True
# 1            True            True         True      True             False
# 2            True            True         True      True              True
# 3            True            True         True      True             False
# 4            True           False         True      True              True
# 5            True           False         True      True             False
# 6            True           False         True      True             False
# 7            True           False         True      True             False
# 8            True           False         True      True             False
# 9            True           False         True      True              True
#
#    Repair (Simple)  Restart Repair  Test Repair
# 0            False           False         True
# 1             True            True         True
# 2            False           False         True
# 3             True           False         True
# 4            False           False         True
# 5             True           False         True
# 6             True            True         True
# 7             True           False         True
# 8             True           False         True
# 9            False           False         True

# %%
# learn to use Apriori algorithm from mlxtend

frequent_itemsets = apriori(data, min_support = 0.4, use_colnames = True)
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   1.000000                                   (Analyze Defect)
# 1   0.905797                                   (Archive Repair)
# 2   0.998188                                      (Inform User)
# 3   1.000000                                         (Register)
# 4   0.596920                                 (Repair (Complex))
# 5   0.438406                                  (Repair (Simple))
# 6   0.998188                                      (Test Repair)
# 7   0.905797                   (Archive Repair, Analyze Defect)
# 8   0.998188                      (Analyze Defect, Inform User)
# 9   1.000000                         (Analyze Defect, Register)
# 10  0.596920                 (Analyze Defect, Repair (Complex))
# 11  0.438406                  (Repair (Simple), Analyze Defect)
# 12  0.998188                      (Test Repair, Analyze Defect)
# 13  0.905797                      (Archive Repair, Inform User)
# 14  0.905797                         (Archive Repair, Register)
# 15  0.550725                 (Archive Repair, Repair (Complex))
# 16  0.905797                      (Archive Repair, Test Repair)
# 17  0.998188                            (Inform User, Register)
# 18  0.595109                    (Repair (Complex), Inform User)
# 19  0.438406                     (Repair (Simple), Inform User)
# 20  0.998188                         (Test Repair, Inform User)
# 21  0.596920                       (Repair (Complex), Register)
# 22  0.438406                        (Repair (Simple), Register)
# 23  0.998188                            (Test Repair, Register)
# 24  0.595109                    (Test Repair, Repair (Complex))
# 25  0.438406                     (Test Repair, Repair (Simple))
# 26  0.905797      (Archive Repair, Analyze Defect, Inform User)
# 27  0.905797         (Archive Repair, Analyze Defect, Register)
# 28  0.550725  (Archive Repair, Analyze Defect, Repair (Compl...
# 29  0.905797      (Archive Repair, Test Repair, Analyze Defect)
# ..       ...                                                ...
# 49  0.438406        (Test Repair, Repair (Simple), Inform User)
# 50  0.595109          (Test Repair, Repair (Complex), Register)
# 51  0.438406           (Test Repair, Repair (Simple), Register)
# 52  0.905797  (Archive Repair, Analyze Defect, Inform User, ...
# 53  0.550725  (Archive Repair, Repair (Complex), Analyze Def...
# 54  0.905797  (Archive Repair, Test Repair, Analyze Defect, ...
# 55  0.550725  (Archive Repair, Analyze Defect, Repair (Compl...
# 56  0.905797  (Archive Repair, Test Repair, Analyze Defect, ...
# 57  0.550725  (Archive Repair, Test Repair, Analyze Defect, ...
# 58  0.595109  (Repair (Complex), Analyze Defect, Inform User...
# 59  0.438406  (Repair (Simple), Analyze Defect, Inform User,...
# 60  0.998188  (Test Repair, Analyze Defect, Inform User, Reg...
# 61  0.595109  (Repair (Complex), Test Repair, Analyze Defect...
# 62  0.438406  (Repair (Simple), Test Repair, Analyze Defect,...
# 63  0.595109  (Test Repair, Analyze Defect, Repair (Complex)...
# 64  0.438406  (Repair (Simple), Test Repair, Analyze Defect,...
# 65  0.550725  (Archive Repair, Repair (Complex), Inform User...
# 66  0.905797  (Archive Repair, Test Repair, Inform User, Reg...
# 67  0.550725  (Archive Repair, Test Repair, Repair (Complex)...
# 68  0.550725  (Archive Repair, Test Repair, Repair (Complex)...
# 69  0.595109  (Test Repair, Repair (Complex), Inform User, R...
# 70  0.438406  (Test Repair, Repair (Simple), Inform User, Re...
# 71  0.550725  (Analyze Defect, Inform User, Register, Archiv...
# 72  0.905797  (Test Repair, Analyze Defect, Inform User, Reg...
# 73  0.550725  (Test Repair, Analyze Defect, Inform User, Arc...
# 74  0.550725  (Test Repair, Analyze Defect, Register, Archiv...
# 75  0.595109  (Test Repair, Analyze Defect, Inform User, Reg...
# 76  0.438406  (Test Repair, Analyze Defect, Inform User, Reg...
# 77  0.550725  (Test Repair, Inform User, Register, Archive R...
# 78  0.550725  (Test Repair, Analyze Defect, Inform User, Reg...
#
# [79 rows x 2 columns]

# %%
# learn to use association rule algorithm from mlxtend

rules_association =arule(frequent_itemsets, metric = 'confidence', min_threshold = 0.7)
rules_association
# Out:
#                                            antecedents  \
# 0                                     (Archive Repair)
# 1                                     (Analyze Defect)
# 2                                     (Analyze Defect)
# 3                                        (Inform User)
# 4                                     (Analyze Defect)
# 5                                           (Register)
# 6                                   (Repair (Complex))
# 7                                    (Repair (Simple))
# 8                                        (Test Repair)
# 9                                     (Analyze Defect)
# 10                                    (Archive Repair)
# 11                                       (Inform User)
# 12                                    (Archive Repair)
# 13                                          (Register)
# 14                                  (Repair (Complex))
# 15                                    (Archive Repair)
# 16                                       (Test Repair)
# 17                                       (Inform User)
# 18                                          (Register)
# 19                                  (Repair (Complex))
# 20                                   (Repair (Simple))
# 21                                       (Test Repair)
# 22                                       (Inform User)
# 23                                  (Repair (Complex))
# 24                                   (Repair (Simple))
# 25                                       (Test Repair)
# 26                                          (Register)
# 27                                  (Repair (Complex))
# 28                                   (Repair (Simple))
# 29                    (Archive Repair, Analyze Defect)
# ..                                                 ...
# 426  (Test Repair, Analyze Defect, Inform User, Arc...
# 427  (Test Repair, Analyze Defect, Register, Archiv...
# 428  (Test Repair, Inform User, Register, Archive R...
# 429  (Analyze Defect, Inform User, Register, Archiv...
# 430  (Test Repair, Analyze Defect, Inform User, Rep...
# 431  (Test Repair, Analyze Defect, Repair (Complex)...
# 432  (Archive Repair, Test Repair, Analyze Defect, ...
# 433  (Test Repair, Repair (Complex), Inform User, R...
# 434  (Archive Repair, Test Repair, Repair (Complex)...
# 435  (Archive Repair, Test Repair, Repair (Complex)...
# 436  (Repair (Complex), Analyze Defect, Inform User...
# 437  (Archive Repair, Repair (Complex), Analyze Def...
# 438  (Archive Repair, Analyze Defect, Repair (Compl...
# 439  (Archive Repair, Repair (Complex), Inform User...
# 440    (Test Repair, Analyze Defect, Repair (Complex))
# 441       (Test Repair, Repair (Complex), Inform User)
# 442          (Test Repair, Repair (Complex), Register)
# 443    (Archive Repair, Test Repair, Repair (Complex))
# 444    (Repair (Complex), Analyze Defect, Inform User)
# 445       (Analyze Defect, Repair (Complex), Register)
# 446  (Archive Repair, Analyze Defect, Repair (Compl...
# 447          (Repair (Complex), Inform User, Register)
# 448    (Archive Repair, Repair (Complex), Inform User)
# 449       (Archive Repair, Repair (Complex), Register)
# 450                    (Test Repair, Repair (Complex))
# 451                 (Analyze Defect, Repair (Complex))
# 452                    (Repair (Complex), Inform User)
# 453                       (Repair (Complex), Register)
# 454                 (Archive Repair, Repair (Complex))
# 455                                 (Repair (Complex))
#
#                                            consequents  antecedent support  \
# 0                                     (Analyze Defect)            0.905797
# 1                                     (Archive Repair)            1.000000
# 2                                        (Inform User)            1.000000
# 3                                     (Analyze Defect)            0.998188
# 4                                           (Register)            1.000000
# 5                                     (Analyze Defect)            1.000000
# 6                                     (Analyze Defect)            0.596920
# 7                                     (Analyze Defect)            0.438406
# 8                                     (Analyze Defect)            0.998188
# 9                                        (Test Repair)            1.000000
# 10                                       (Inform User)            0.905797
# 11                                    (Archive Repair)            0.998188
# 12                                          (Register)            0.905797
# 13                                    (Archive Repair)            1.000000
# 14                                    (Archive Repair)            0.596920
# 15                                       (Test Repair)            0.905797
# 16                                    (Archive Repair)            0.998188
# 17                                          (Register)            0.998188
# 18                                       (Inform User)            1.000000
# 19                                       (Inform User)            0.596920
# 20                                       (Inform User)            0.438406
# 21                                       (Inform User)            0.998188
# 22                                       (Test Repair)            0.998188
# 23                                          (Register)            0.596920
# 24                                          (Register)            0.438406
# 25                                          (Register)            0.998188
# 26                                       (Test Repair)            1.000000
# 27                                       (Test Repair)            0.596920
# 28                                       (Test Repair)            0.438406
# 29                                       (Inform User)            0.905797
# ..                                                 ...                 ...
# 426                                         (Register)            0.550725
# 427                                      (Inform User)            0.550725
# 428                                   (Analyze Defect)            0.550725
# 429                                      (Test Repair)            0.550725
# 430                         (Archive Repair, Register)            0.595109
# 431                      (Archive Repair, Inform User)            0.595109
# 432                            (Inform User, Register)            0.550725
# 433                   (Archive Repair, Analyze Defect)            0.595109
# 434                         (Analyze Defect, Register)            0.550725
# 435                      (Analyze Defect, Inform User)            0.550725
# 436                      (Archive Repair, Test Repair)            0.595109
# 437                            (Test Repair, Register)            0.550725
# 438                         (Test Repair, Inform User)            0.550725
# 439                      (Test Repair, Analyze Defect)            0.550725
# 440            (Archive Repair, Inform User, Register)            0.595109
# 441         (Archive Repair, Analyze Defect, Register)            0.595109
# 442      (Archive Repair, Analyze Defect, Inform User)            0.595109
# 443            (Analyze Defect, Inform User, Register)            0.550725
# 444            (Archive Repair, Test Repair, Register)            0.595109
# 445         (Archive Repair, Test Repair, Inform User)            0.596920
# 446               (Test Repair, Inform User, Register)            0.550725
# 447      (Archive Repair, Test Repair, Analyze Defect)            0.595109
# 448            (Test Repair, Analyze Defect, Register)            0.550725
# 449         (Test Repair, Analyze Defect, Inform User)            0.550725
# 450  (Archive Repair, Analyze Defect, Inform User, ...            0.595109
# 451  (Archive Repair, Test Repair, Inform User, Reg...            0.596920
# 452  (Archive Repair, Test Repair, Analyze Defect, ...            0.595109
# 453  (Archive Repair, Test Repair, Analyze Defect, ...            0.596920
# 454  (Test Repair, Analyze Defect, Inform User, Reg...            0.550725
# 455  (Test Repair, Analyze Defect, Inform User, Reg...            0.596920
#
#      consequent support   support  confidence      lift  leverage  conviction
# 0              1.000000  0.905797    1.000000  1.000000  0.000000         inf
# 1              0.905797  0.905797    0.905797  1.000000  0.000000    1.000000
# 2              0.998188  0.998188    0.998188  1.000000  0.000000    1.000000
# 3              1.000000  0.998188    1.000000  1.000000  0.000000         inf
# 4              1.000000  1.000000    1.000000  1.000000  0.000000         inf
# 5              1.000000  1.000000    1.000000  1.000000  0.000000         inf
# 6              1.000000  0.596920    1.000000  1.000000  0.000000         inf
# 7              1.000000  0.438406    1.000000  1.000000  0.000000         inf
# 8              1.000000  0.998188    1.000000  1.000000  0.000000         inf
# 9              0.998188  0.998188    0.998188  1.000000  0.000000    1.000000
# 10             0.998188  0.905797    1.000000  1.001815  0.001641         inf
# 11             0.905797  0.905797    0.907441  1.001815  0.001641    1.017761
# 12             1.000000  0.905797    1.000000  1.000000  0.000000         inf
# 13             0.905797  0.905797    0.905797  1.000000  0.000000    1.000000
# 14             0.905797  0.550725    0.922610  1.018561  0.010036    1.217249
# 15             0.998188  0.905797    1.000000  1.001815  0.001641         inf
# 16             0.905797  0.905797    0.907441  1.001815  0.001641    1.017761
# 17             1.000000  0.998188    1.000000  1.000000  0.000000         inf
# 18             0.998188  0.998188    0.998188  1.000000  0.000000    1.000000
# 19             0.998188  0.595109    0.996965  0.998774 -0.000730    0.596920
# 20             0.998188  0.438406    1.000000  1.001815  0.000794         inf
# 21             0.998188  0.998188    1.000000  1.001815  0.001808         inf
# 22             0.998188  0.998188    1.000000  1.001815  0.001808         inf
# 23             1.000000  0.596920    1.000000  1.000000  0.000000         inf
# 24             1.000000  0.438406    1.000000  1.000000  0.000000         inf
# 25             1.000000  0.998188    1.000000  1.000000  0.000000         inf
# 26             0.998188  0.998188    0.998188  1.000000  0.000000    1.000000
# 27             0.998188  0.595109    0.996965  0.998774 -0.000730    0.596920
# 28             0.998188  0.438406    1.000000  1.001815  0.000794         inf
# 29             0.998188  0.905797    1.000000  1.001815  0.001641         inf
# ..                  ...       ...         ...       ...       ...         ...
# 426            1.000000  0.550725    1.000000  1.000000  0.000000         inf
# 427            0.998188  0.550725    1.000000  1.001815  0.000998         inf
# 428            1.000000  0.550725    1.000000  1.000000  0.000000         inf
# 429            0.998188  0.550725    1.000000  1.001815  0.000998         inf
# 430            0.905797  0.550725    0.925419  1.021662  0.011677    1.263088
# 431            0.905797  0.550725    0.925419  1.021662  0.011677    1.263088
# 432            0.998188  0.550725    1.000000  1.001815  0.000998         inf
# 433            0.905797  0.550725    0.925419  1.021662  0.011677    1.263088
# 434            1.000000  0.550725    1.000000  1.000000  0.000000         inf
# 435            0.998188  0.550725    1.000000  1.001815  0.000998         inf
# 436            0.905797  0.550725    0.925419  1.021662  0.011677    1.263088
# 437            0.998188  0.550725    1.000000  1.001815  0.000998         inf
# 438            0.998188  0.550725    1.000000  1.001815  0.000998         inf
# 439            0.998188  0.550725    1.000000  1.001815  0.000998         inf
# 440            0.905797  0.550725    0.925419  1.021662  0.011677    1.263088
# 441            0.905797  0.550725    0.925419  1.021662  0.011677    1.263088
# 442            0.905797  0.550725    0.925419  1.021662  0.011677    1.263088
# 443            0.998188  0.550725    1.000000  1.001815  0.000998         inf
# 444            0.905797  0.550725    0.925419  1.021662  0.011677    1.263088
# 445            0.905797  0.550725    0.922610  1.018561  0.010036    1.217249
# 446            0.998188  0.550725    1.000000  1.001815  0.000998         inf
# 447            0.905797  0.550725    0.925419  1.021662  0.011677    1.263088
# 448            0.998188  0.550725    1.000000  1.001815  0.000998         inf
# 449            0.998188  0.550725    1.000000  1.001815  0.000998         inf
# 450            0.905797  0.550725    0.925419  1.021662  0.011677    1.263088
# 451            0.905797  0.550725    0.922610  1.018561  0.010036    1.217249
# 452            0.905797  0.550725    0.925419  1.021662  0.011677    1.263088
# 453            0.905797  0.550725    0.922610  1.018561  0.010036    1.217249
# 454            0.998188  0.550725    1.000000  1.001815  0.000998         inf
# 455            0.905797  0.550725    0.922610  1.018561  0.010036    1.217249
#
# [456 rows x 9 columns]

# %% [markdown]
# ## Section 2.2: exercises for filtering out qualified frequent itemsets and association rules

# %%
# read file '2012.csv' and turn the data format for Apriori algorithm

data_set = []

with open("2012.csv") as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        data_set.append(row)

te = TransactionEncoder()
te_ary = te.fit(data_set).transform(data_set)
data = pd.DataFrame(te_ary, columns = te.columns_)
data.head(10)
# Out:
#    A_ACCEPTED  A_ACTIVATED  A_APPROVED  A_CANCELLED  A_DECLINED  A_FINALIZED  \
# 0        True         True        True        False       False         True
# 1        True         True        True        False       False         True
# 2        True         True        True        False       False         True
# 3       False        False       False        False        True        False
# 4       False        False       False        False        True        False
# 5       False        False       False         True       False        False
# 6       False        False       False        False        True        False
# 7       False        False       False         True       False        False
# 8       False        False       False         True       False        False
# 9        True        False       False        False        True         True
#
#    A_PARTLYSUBMITTED  A_PREACCEPTED  A_REGISTERED  A_SUBMITTED  \
# 0               True           True          True         True
# 1               True           True          True         True
# 2               True           True          True         True
# 3               True          False         False         True
# 4               True          False         False         True
# 5               True           True         False         True
# 6               True           True         False         True
# 7               True           True         False         True
# 8               True           True         False         True
# 9               True           True         False         True
#
#               ...               O_SELECTED  O_SENT  O_SENT_BACK  \
# 0             ...                     True    True         True
# 1             ...                     True    True         True
# 2             ...                     True    True         True
# 3             ...                    False   False        False
# 4             ...                    False   False        False
# 5             ...                    False   False        False
# 6             ...                    False   False        False
# 7             ...                    False   False        False
# 8             ...                    False   False        False
# 9             ...                     True    True         True
#
#    W_Afhandelen leads  W_Beoordelen fraude  W_Completeren aanvraag  \
# 0               False                False                    True
# 1               False                False                    True
# 2               False                False                    True
# 3               False                False                   False
# 4               False                False                   False
# 5               False                False                    True
# 6                True                False                    True
# 7               False                False                    True
# 8                True                False                    True
# 9               False                False                    True
#
#    W_Nabellen incomplete dossiers  W_Nabellen offertes  W_Valideren aanvraag  \
# 0                           False                 True                  True
# 1                           False                 True                  True
# 2                           False                 True                  True
# 3                           False                False                 False
# 4                           False                False                 False
# 5                           False                False                 False
# 6                           False                False                 False
# 7                           False                False                 False
# 8                           False                False                 False
# 9                           False                 True                  True
#
#    W_Wijzigen contractgegevens
# 0                        False
# 1                        False
# 2                         True
# 3                        False
# 4                        False
# 5                        False
# 6                        False
# 7                        False
# 8                        False
# 9                        False
#
# [10 rows x 24 columns]

# %%
# Question 7: mine frequent itemsets from the transaction set 'data' 
# and store the found itemsets in variable 'frequent_itemsets', set minimum support to 0.2 ??????

frequent_itemsets = apriori(data, min_support = 0.2, use_colnames = True)

# Question 8: add another column named 'length' in 'frequent_itemsets' which indicates the number of items in each frequent itemset ??????

frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

# Question 9: filter out the frequent itemsets which have a length longer than 5 and a support bigger than 0.3 
# and store these found itemsets in variable 'frequent_itemsets_filtered' ??????

frequent_itemsets_filtered = frequent_itemsets.loc[(frequent_itemsets['length'] > 5) & (frequent_itemsets['support'] > 0.3)]

frequent_itemsets_filtered
# Out:
#        support                                           itemsets  length
# 2000  0.383205  (O_CREATED, A_PREACCEPTED, A_PARTLYSUBMITTED, ...       6
# 2001  0.383205  (A_PREACCEPTED, O_SELECTED, A_PARTLYSUBMITTED,...       6
# 2002  0.383205  (O_SENT, A_PREACCEPTED, A_PARTLYSUBMITTED, A_S...       6
# 2004  0.383205  (A_PREACCEPTED, A_PARTLYSUBMITTED, A_SUBMITTED...       6
# 2005  0.383205  (A_PREACCEPTED, A_PARTLYSUBMITTED, A_SUBMITTED...       6
# 2012  0.383205  (O_CREATED, A_PREACCEPTED, O_SELECTED, A_PARTL...       6
# 2013  0.383205  (O_CREATED, O_SENT, A_PREACCEPTED, A_PARTLYSUB...       6
# 2015  0.383205  (O_CREATED, A_PREACCEPTED, A_PARTLYSUBMITTED, ...       6
# 2016  0.383205  (O_CREATED, A_PREACCEPTED, A_PARTLYSUBMITTED, ...       6
# 2018  0.383205  (O_SENT, A_PREACCEPTED, O_SELECTED, A_PARTLYSU...       6
# 2020  0.383205  (A_PREACCEPTED, O_SELECTED, A_PARTLYSUBMITTED,...       6
# 2021  0.383205  (A_PREACCEPTED, O_SELECTED, A_PARTLYSUBMITTED,...       6
# 2024  0.383205  (O_SENT, A_PREACCEPTED, A_PARTLYSUBMITTED, A_F...       6
# 2025  0.383205  (O_SENT, A_PREACCEPTED, A_PARTLYSUBMITTED, A_F...       6
# 2030  0.383205  (A_PREACCEPTED, A_PARTLYSUBMITTED, A_FINALIZED...       6
# 2038  0.383205  (O_CREATED, O_SELECTED, A_PARTLYSUBMITTED, A_S...       6
# 2039  0.383205  (O_CREATED, O_SENT, A_PARTLYSUBMITTED, A_SUBMI...       6
# 2041  0.383205  (O_CREATED, A_PARTLYSUBMITTED, A_SUBMITTED, A_...       6
# 2042  0.383205  (O_CREATED, A_PARTLYSUBMITTED, A_SUBMITTED, A_...       6
# 2044  0.383205  (O_SENT, O_SELECTED, A_PARTLYSUBMITTED, A_SUBM...       6
# 2046  0.383205  (O_SELECTED, A_PARTLYSUBMITTED, A_SUBMITTED, A...       6
# 2047  0.383205  (O_SELECTED, A_PARTLYSUBMITTED, A_SUBMITTED, A...       6
# 2050  0.383205  (O_SENT, A_PARTLYSUBMITTED, A_SUBMITTED, A_FIN...       6
# 2051  0.383205  (O_SENT, A_PARTLYSUBMITTED, A_SUBMITTED, A_FIN...       6
# 2056  0.383205  (A_PARTLYSUBMITTED, A_SUBMITTED, A_FINALIZED, ...       6
# 2069  0.383205  (O_CREATED, O_SENT, O_SELECTED, A_PARTLYSUBMIT...       6
# 2071  0.383205  (O_CREATED, O_SELECTED, A_PARTLYSUBMITTED, A_F...       6
# 2072  0.383205  (O_CREATED, O_SELECTED, A_PARTLYSUBMITTED, A_F...       6
# 2075  0.383205  (O_CREATED, O_SENT, A_PARTLYSUBMITTED, A_FINAL...       6
# 2076  0.383205  (O_CREATED, O_SENT, A_PARTLYSUBMITTED, A_FINAL...       6
# ...        ...                                                ...     ...
# 4391  0.383205  (O_CREATED, O_SENT, A_PREACCEPTED, O_SELECTED,...       8
# 4417  0.383205  (O_CREATED, O_SENT, O_SELECTED, A_SUBMITTED, A...       8
# 4454  0.383205  (O_CREATED, A_PREACCEPTED, O_SELECTED, A_PARTL...       8
# 4455  0.383205  (O_CREATED, A_PREACCEPTED, O_SELECTED, A_PARTL...       8
# 4460  0.383205  (O_CREATED, A_PREACCEPTED, O_SELECTED, A_PARTL...       8
# 4466  0.383205  (O_CREATED, A_PREACCEPTED, A_PARTLYSUBMITTED, ...       8
# 4476  0.383205  (A_PREACCEPTED, O_SELECTED, A_PARTLYSUBMITTED,...       8
# 4496  0.383205  (O_CREATED, A_PREACCEPTED, O_SELECTED, A_PARTL...       8
# 4522  0.383205  (O_CREATED, O_SELECTED, A_PARTLYSUBMITTED, A_S...       8
# 4556  0.383205  (O_CREATED, A_PREACCEPTED, O_SELECTED, A_SUBMI...       8
# 4602  0.383205  (O_CREATED, A_PREACCEPTED, O_SELECTED, A_PARTL...       8
# 4603  0.383205  (O_CREATED, A_PREACCEPTED, O_SELECTED, A_PARTL...       8
# 4608  0.383205  (O_CREATED, A_PREACCEPTED, O_SELECTED, A_PARTL...       8
# 4614  0.383205  (O_CREATED, A_PREACCEPTED, A_PARTLYSUBMITTED, ...       8
# 4624  0.383205  (A_PREACCEPTED, O_SELECTED, A_PARTLYSUBMITTED,...       8
# 4644  0.383205  (O_CREATED, A_PREACCEPTED, O_SELECTED, A_PARTL...       8
# 4670  0.383205  (O_CREATED, O_SELECTED, A_PARTLYSUBMITTED, A_S...       8
# 4704  0.383205  (O_CREATED, A_PREACCEPTED, O_SELECTED, A_SUBMI...       8
# 4747  0.383205  (O_CREATED, A_PREACCEPTED, O_SELECTED, A_PARTL...       8
# 4803  0.383205  (O_CREATED, O_SENT, A_PREACCEPTED, O_SELECTED,...       9
# 4804  0.383205  (O_CREATED, O_SENT, A_PREACCEPTED, O_SELECTED,...       9
# 4809  0.383205  (O_CREATED, A_PREACCEPTED, O_SELECTED, A_PARTL...       9
# 4815  0.383205  (O_CREATED, O_SENT, A_PREACCEPTED, A_PARTLYSUB...       9
# 4825  0.383205  (O_SENT, A_PREACCEPTED, O_SELECTED, A_PARTLYSU...       9
# 4845  0.383205  (O_CREATED, O_SENT, A_PREACCEPTED, O_SELECTED,...       9
# 4871  0.383205  (O_CREATED, O_SENT, O_SELECTED, A_PARTLYSUBMIT...       9
# 4905  0.383205  (O_CREATED, O_SENT, A_PREACCEPTED, O_SELECTED,...       9
# 4948  0.383205  (O_CREATED, A_PREACCEPTED, O_SELECTED, A_PARTL...       9
# 5001  0.383205  (O_CREATED, A_PREACCEPTED, O_SELECTED, A_PARTL...       9
# 5065  0.383205  (O_CREATED, O_SENT, A_PREACCEPTED, O_SELECTED,...      10
#
# [386 rows x 3 columns]

# %%
# Question 10: mine association rules from the discovered frequent itemsets stored in variable 'frequent_itemsets', set minimum confidence to 0.7
# store the discovered rules in variable 'rules_association' ??????

rules_association = arule(frequent_itemsets, metric = 'confidence', min_threshold = 0.5)

# Question 11: filter out the rules with lift larger than 1 and support larger than 0.4, store the discovered rules in variable 'filtered_rules' ??????

filtered_rules = rules_association.loc[(rules_association['lift'] > 1) & (rules_association['support'] > 0.4)]

# show the columns 'antecedents', 'consequents', 'support', 'confidence' and 'lift' of variable 'filtered_rules' 
filtered_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
# Out:
#                                             antecedents  \
# 75                                      (A_PREACCEPTED)
# 76                             (W_Completeren aanvraag)
# 842                  (A_PARTLYSUBMITTED, A_PREACCEPTED)
# 843         (A_PARTLYSUBMITTED, W_Completeren aanvraag)
# 846                                     (A_PREACCEPTED)
# 847                            (W_Completeren aanvraag)
# 1031                       (A_SUBMITTED, A_PREACCEPTED)
# 1032              (A_SUBMITTED, W_Completeren aanvraag)
# 1035                                    (A_PREACCEPTED)
# 1036                           (W_Completeren aanvraag)
# 6193    (A_SUBMITTED, A_PREACCEPTED, A_PARTLYSUBMITTED)
# 6195  (A_SUBMITTED, A_PARTLYSUBMITTED, W_Completeren...
# 6197                       (A_SUBMITTED, A_PREACCEPTED)
# 6199              (A_SUBMITTED, W_Completeren aanvraag)
# 6200                 (A_PARTLYSUBMITTED, A_PREACCEPTED)
# 6202        (A_PARTLYSUBMITTED, W_Completeren aanvraag)
# 6204                                    (A_PREACCEPTED)
# 6206                           (W_Completeren aanvraag)
#
#                                             consequents   support  confidence  \
# 75                             (W_Completeren aanvraag)  0.562925         1.0
# 76                                      (A_PREACCEPTED)  0.562925         1.0
# 842                            (W_Completeren aanvraag)  0.562925         1.0
# 843                                     (A_PREACCEPTED)  0.562925         1.0
# 846         (A_PARTLYSUBMITTED, W_Completeren aanvraag)  0.562925         1.0
# 847                  (A_PARTLYSUBMITTED, A_PREACCEPTED)  0.562925         1.0
# 1031                           (W_Completeren aanvraag)  0.562925         1.0
# 1032                                    (A_PREACCEPTED)  0.562925         1.0
# 1035              (A_SUBMITTED, W_Completeren aanvraag)  0.562925         1.0
# 1036                       (A_SUBMITTED, A_PREACCEPTED)  0.562925         1.0
# 6193                           (W_Completeren aanvraag)  0.562925         1.0
# 6195                                    (A_PREACCEPTED)  0.562925         1.0
# 6197        (A_PARTLYSUBMITTED, W_Completeren aanvraag)  0.562925         1.0
# 6199                 (A_PARTLYSUBMITTED, A_PREACCEPTED)  0.562925         1.0
# 6200              (A_SUBMITTED, W_Completeren aanvraag)  0.562925         1.0
# 6202                       (A_SUBMITTED, A_PREACCEPTED)  0.562925         1.0
# 6204  (A_SUBMITTED, A_PARTLYSUBMITTED, W_Completeren...  0.562925         1.0
# 6206    (A_SUBMITTED, A_PREACCEPTED, A_PARTLYSUBMITTED)  0.562925         1.0
#
#           lift
# 75    1.776435
# 76    1.776435
# 842   1.776435
# 843   1.776435
# 846   1.776435
# 847   1.776435
# 1031  1.776435
# 1032  1.776435
# 1035  1.776435
# 1036  1.776435
# 6193  1.776435
# 6195  1.776435
# 6197  1.776435
# 6199  1.776435
# 6200  1.776435
# 6202  1.776435
# 6204  1.776435
# 6206  1.776435
